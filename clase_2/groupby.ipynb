# %%
import pandas as pd
# Out:
# /Users/ricalanis/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
cities_df = pd.read_csv('Cities.csv')

# %%
cities_df.head(5)
# Out:
#        city         country  latitude  longitude  temperature
# 0   Aalborg         Denmark     57.03       9.92         7.52
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2    Abisko          Sweden     63.35      18.83         0.20
# 3     Adana          Turkey     36.99      35.32        18.67
# 4  Albacete           Spain     39.00      -1.87        12.62

# %%
cities_df.value_counts()
# Out:
# city       country         latitude  longitude  temperature
# Aalborg    Denmark         57.03      9.92      7.52           1
# Malmö      Sweden          55.58      13.03     7.33           1
# Marbella   Spain           36.52     -4.88      17.19          1
# Marseille  France          43.29      5.38      14.98          1
# Mazyr      Belarus         52.05      29.27     6.25           1
#                                                               ..
# Dublin     Ireland         53.33     -6.25      8.49           1
# Dundee     United Kingdom  56.47     -3.00      6.40           1
# Edinburgh  United Kingdom  55.95     -3.22      7.43           1
# Edirne     Turkey          41.67      26.57     10.90          1
# Zurich     Switzerland     47.38      8.56      6.68           1
# Length: 213, dtype: int64

# %%
cities_df['latitude_dec'] = cities_df['latitude'].astype(str).apply(lambda x: str(x)[0])

# %%
grouped = cities_df.groupby('country')

# %%
countries_df = pd.read_csv('Countries.csv')

# %%
# Out:
#                    country  population   EU coastline
# 0                  Albania        2.90   no       yes
# 1                  Andorra        0.07   no        no
# 2                  Austria        8.57  yes        no
# 3                  Belarus        9.48   no        no
# 4                  Belgium       11.37  yes       yes
# 5   Bosnia and Herzegovina        3.80   no       yes
# 6                 Bulgaria        7.10  yes       yes
# 7                  Croatia        4.23  yes       yes
# 8                   Cyprus        1.18  yes       yes
# 9           Czech Republic       10.55  yes        no
# 10                 Denmark        5.69  yes       yes
# 11                 Estonia        1.31  yes       yes
# 12                 Finland        5.52  yes       yes
# 13                  France       64.67  yes       yes
# 14                 Germany       80.68  yes       yes
# 15                  Greece       10.92  yes       yes
# ...

# %%
grouped.apply(sum)
# Out:
#                                                                      city  \
# country
# Albania                                                           Elbasan
# Andorra                                                           Andorra
# Austria                                   GrazInnsbruckLinzSalzburgVienna
# Belarus                                   BrestHrodnaMazyrMinskOrshaPinsk
# Belgium                                                            Brugge
# Bosnia and Herzegovina                                           Sarajevo
# Bulgaria                              BurgasPlevenPlovdivRuseStara Zagora
# Croatia                                                       RijekaSplit
# Czech Republic                                          BrnoOstravaPrague
# Denmark                                                     AalborgOdense
# Estonia                                                      TallinnTartu
# ...

# %%
def len_int(x):
    return len(str(x))

# %%
cities_df.groupby('country')['temperature'].agg(sum)
# Out:
# country
# Albania                    15.18
# Andorra                     9.60
# Austria                    30.72
# Belarus                    35.68
# Belgium                     9.65
# Bosnia and Herzegovina      9.60
# Bulgaria                   52.20
# Croatia                    21.73
# Czech Republic             23.57
# Denmark                    15.25
# Estonia                     9.18
# Finland                    13.95
# France                    182.72
# Germany                   110.17
# Greece                     67.61
# Hungary                    38.41
# Ireland                    27.90
# Italy                     202.12
# Latvia                     10.54
# Lithuania                  18.43
# Macedonia                   9.36
# Moldova                    16.83
# Montenegro                  9.99
# Netherlands                26.27
# Norway                     18.63
# Poland                     65.25
# Portugal                   28.94
# Romania                    83.02
# ...

# %%
cities_countries_df = cities_df.merge(countries_df, on='country')

# %%
cities_countries_df['city']
# Out:
# 0         Aalborg
# 1          Odense
# 2        Aberdeen
# 3         Belfast
# 4      Birmingham
#           ...
# 208         Split
# 209      Sarajevo
# 210        Skopje
# 211       Tallinn
# 212         Tartu
# Name: city, Length: 213, dtype: object

# %%
cities_countries_df['country']
# Out:
# 0                     Denmark
# 1                     Denmark
# 2              United Kingdom
# 3              United Kingdom
# 4              United Kingdom
#                 ...
# 208                   Croatia
# 209    Bosnia and Herzegovina
# 210                 Macedonia
# 211                   Estonia
# 212                   Estonia
# Name: country, Length: 213, dtype: object

# %%
cities_countries_df.iloc[[0],]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-13fb8ad9d9ba> in <module>
# ----> 1 cities_countries_df.iat([0],['Country'])
#
# TypeError: '_iAtIndexer' object is not callable

# %%
cities_countries_df.keys()
# Out:
# Index(['city', 'country', 'latitude', 'longitude', 'temperature',
#        'latitude_dec', 'population', 'EU', 'coastline'],
#       dtype='object')

# %%
cities_df.iloc[0:5]
# Out:
#        city         country  latitude  longitude  temperature latitude_dec
# 0   Aalborg         Denmark     57.03       9.92         7.52            5
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10            5
# 2    Abisko          Sweden     63.35      18.83         0.20            6
# 3     Adana          Turkey     36.99      35.32        18.67            3
# 4  Albacete           Spain     39.00      -1.87        12.62            3

# %%
cities_df.loc[208:]
# Out:
#             city      country  latitude  longitude  temperature latitude_dec
# 208  Yevpatoriya      Ukraine     45.20      33.36        10.02            4
# 209     Zaragoza        Spain     41.65      -0.89        14.17            4
# 210     Zhytomyr      Ukraine     50.25      28.66         6.67            5
# 211    Zonguldak       Turkey     41.43      31.78        10.64            4
# 212       Zurich  Switzerland     47.38       8.56         6.68            4

# %%
cities_df[cities_df['temperature'] >10]
# Out:
#             city  country  latitude  longitude  temperature latitude_dec
# 3          Adana   Turkey     36.99      35.32        18.67            3
# 4       Albacete    Spain     39.00      -1.87        12.62            3
# 5      Algeciras    Spain     36.13      -5.47        17.38            3
# 6         Amiens   France     49.90       2.30        10.17            4
# 8         Ancona    Italy     43.60      13.50        13.52            4
# ..           ...      ...       ...        ...          ...          ...
# 202     Valencia    Spain     39.49      -0.40        16.02            3
# 204         Vigo    Spain     42.22      -8.73        12.85            4
# 208  Yevpatoriya  Ukraine     45.20      33.36        10.02            4
# 209     Zaragoza    Spain     41.65      -0.89        14.17            4
# 211    Zonguldak   Turkey     41.43      31.78        10.64            4
#
# [79 rows x 6 columns]

# %%
def hala_madrid(x):
    if x == 'Spain': return True
    return False

# %%
cities_df[cities_df['country'].apply(lambda x: hala_madrid(x))]
# Out:
#           city country  latitude  longitude  temperature latitude_dec
# 4     Albacete   Spain     39.00      -1.87        12.62            3
# 5    Algeciras   Spain     36.13      -5.47        17.38            3
# 17     Badajoz   Spain     38.88      -6.97        15.61            3
# 20   Barcelona   Spain     41.38       2.18        15.78            4
# 32      Bilbao   Spain     43.25      -2.93        11.41            4
# 53      Burgos   Spain     42.35      -3.68        10.45            4
# 59   Cartagena   Spain     37.60      -0.98        17.32            3
# 94     Granada   Spain     37.16      -3.59        16.33            3
# 103     Huelva   Spain     37.25      -6.93        17.09            3
# 130     Madrid   Spain     40.40      -3.68        11.19            4
# 136   Marbella   Spain     36.52      -4.88        17.19            3
# 145     Murcia   Spain     37.98      -1.13        15.00            3
# ...

# %%
cities_df['temperature'] = 2

# %%
cities_df
# Out:
#             city         country  latitude  longitude  temperature  \
# 0        Aalborg         Denmark     57.03       9.92            2
# 1       Aberdeen  United Kingdom     57.17      -2.08            2
# 2         Abisko          Sweden     63.35      18.83            2
# 3          Adana          Turkey     36.99      35.32            2
# 4       Albacete           Spain     39.00      -1.87            2
# ..           ...             ...       ...        ...          ...
# 208  Yevpatoriya         Ukraine     45.20      33.36            2
# 209     Zaragoza           Spain     41.65      -0.89            2
# 210     Zhytomyr         Ukraine     50.25      28.66            2
# 211    Zonguldak          Turkey     41.43      31.78            2
# 212       Zurich     Switzerland     47.38       8.56            2
#
#     latitude_dec
# 0              5
# 1              5
# 2              6
# 3              3
# 4              3
# ..           ...
# 208            4
# ...
