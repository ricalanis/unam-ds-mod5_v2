# %%
import pandas as pd
# Out:
# /Users/ricalanis/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
mm_df = pd.read_csv('mm.csv', encoding='latin-1')

# %%
mm_df
# Out:
#        ANIO_NACIMIENTO  MES_NACIMIENTO  MES_NACIMIENTOD  DIA_NACIMIENTO  EDAD  \
# 0                    0               0  NO ESPECIFICADO               0    35
# 1                    0               0  NO ESPECIFICADO               0    20
# 2                 1962               7            JULIO              12    39
# 3                 1974               2          FEBRERO              10    27
# 4                 1980               4            ABRIL              18    20
# ...                ...             ...              ...             ...   ...
# 19927             1985               7            JULIO              16    33
# 19928             2001               8           AGOSTO              31    17
# 19929             2004               3            MARZO               7    14
# 19930             1991               8           AGOSTO               7    27
# 19931             1983               5             MAYO              15    36
#
# ...

# %%
mm_df.head(5)
# Out:
#    ANIO_NACIMIENTO  MES_NACIMIENTO  MES_NACIMIENTOD  DIA_NACIMIENTO  EDAD  \
# 0                0               0  NO ESPECIFICADO               0    35
# 1                0               0  NO ESPECIFICADO               0    20
# 2             1962               7            JULIO              12    39
# 3             1974               2          FEBRERO              10    27
# 4             1980               4            ABRIL              18    20
#
#    ESTADO_CONYUGAL ESTADO_CONYUGALD  ENTIDAD_RESIDENCIA ENTIDAD_RESIDENCIAD  \
# 0                4      UNION LIBRE                   8           CHIHUAHUA
# 1                5           CASADO                   8           CHIHUAHUA
# 2                5           CASADO                  12            GUERRERO
# 3                5           CASADO                  12            GUERRERO
# 4                4      UNION LIBRE                  18             NAYARIT
#
# ...

# %%
mm_df.tail(5)
# Out:
#        ANIO_NACIMIENTO  MES_NACIMIENTO MES_NACIMIENTOD  DIA_NACIMIENTO  EDAD  \
# 19927             1985               7           JULIO              16    33
# 19928             2001               8          AGOSTO              31    17
# 19929             2004               3           MARZO               7    14
# 19930             1991               8          AGOSTO               7    27
# 19931             1983               5            MAYO              15    36
#
#        ESTADO_CONYUGAL ESTADO_CONYUGALD  ENTIDAD_RESIDENCIA  \
# 19927                5           CASADO                  28
# 19928                1          SOLTERO                  28
# 19929                4      UNION LIBRE                  28
# 19930                5           CASADO                  28
# 19931                4      UNION LIBRE                  28
#
#       ENTIDAD_RESIDENCIAD  MUNICIPIO_RESIDENCIA  ... DIA_REGISTRO  \
# 19927          TAMAULIPAS                     3  ...           20
# ...

# %%
mm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19932 entries, 0 to 19931
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ANIO_NACIMIENTO            19932 non-null  int64
#  1   MES_NACIMIENTO             19932 non-null  int64
#  2   MES_NACIMIENTOD            19932 non-null  object
#  3   DIA_NACIMIENTO             19932 non-null  int64
#  4   EDAD                       19932 non-null  int64
#  5   ESTADO_CONYUGAL            19932 non-null  int64
#  6   ESTADO_CONYUGALD           19932 non-null  object
#  7   ENTIDAD_RESIDENCIA         19932 non-null  int64
#  8   ENTIDAD_RESIDENCIAD        19932 non-null  object
#  9   MUNICIPIO_RESIDENCIA       19932 non-null  int64
#  10  MUNICIPIO_RESIDENCIAD      19932 non-null  object
#  11  LOCALIDAD_RESIDENCIA       19932 non-null  int64
#  12  LOCALIDAD_RESIDENCIAD      19932 non-null  object
# ...

# %%
mm_df.describe()
# Out:
#        ANIO_NACIMIENTO  MES_NACIMIENTO  DIA_NACIMIENTO          EDAD  \
# count     19932.000000    19932.000000    19932.000000  19932.000000
# mean       1973.453743        4.128035       10.653923     29.694311
# std         122.452316        3.830743       10.165241     35.122756
# min           0.000000        0.000000        0.000000     11.000000
# 25%        1975.000000        0.000000        0.000000     22.000000
# 50%        1981.000000        3.000000        9.000000     28.000000
# 75%        1988.000000        7.000000       19.000000     34.000000
# max        2005.000000       12.000000       31.000000    998.000000
#
#        ESTADO_CONYUGAL  ENTIDAD_RESIDENCIA  MUNICIPIO_RESIDENCIA  \
# count     19932.000000        19932.000000          19932.000000
# mean          3.878236           16.244180             58.133604
# std           1.478145            7.853618             73.450325
# min           0.000000            0.000000              0.000000
# ...

# %%
mm_df['ANIO_NACIMIENTO']
# Out:
# 0           0
# 1           0
# 2        1962
# 3        1974
# 4        1980
#          ...
# 19927    1985
# 19928    2001
# 19929    2004
# 19930    1991
# 19931    1983
# Name: ANIO_NACIMIENTO, Length: 19932, dtype: int64

# %%
mm_df['ANIO_NACIMIENTO'].value_counts()
# Out:
# 1981    820
# 1980    814
# 1982    810
# 1984    809
# 1983    794
#        ...
# 1938      1
# 1927      1
# 1953      1
# 1932      1
# 1906      1
# Name: ANIO_NACIMIENTO, Length: 86, dtype: int64
